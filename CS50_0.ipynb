# %%
# %load_ext sql
# %sql sqlite:///SQL/src0/longlist.db
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# # Show initt

# %%
# %%sql
# SELECT * FROM longlist LIMIT 5
# Out:
#  * sqlite:///SQL/src0/longlist.db
# Done.
# [('9788439736967', 'Boulder', 'Eva Baltasar', "Nicole d'Amonville Alegría", 'paperback', 112, 'Literatura Random House', '2022-08-02', 2023, 2779, 3.77),
#  ('9781628971538', 'Whale', 'Cheon Myeong-Kwan', 'Jae Won Chung', 'paperback', 368, 'Europa Editions', '2023-01-19', 2023, 175, 3.97),
#  ('9781642861181', 'The Gospel According to the New World', 'Maryse Condé', 'Richard Philcox', 'paperback', 184, 'World Editions', '2023-03-07', 2023, 114, 3.05),
#  ('9781529414431', 'Standing Heavy', 'Gauz', 'Frank Wynne', 'paperback', 252, 'MacLehose Press', '2022-05-26', 2023, 322, 3.57),
#  ('9781474623025', 'Time Shelter', 'Georgi Gospodinov', 'Angela Rodel', 'hardcover', 304, 'W&N', '2022-04-21', 2023, 3142, 4.05)]

# %% [markdown]
# # Select 'title'

# %%
# %%sql
# SELECT "title" FROM "longlist" limit 2
# Out:
#  * sqlite:///SQL/src0/longlist.db
# Done.
# [('Boulder',), ('Whale',)]

# %% [markdown]
# #Select "title" and author

# %%
# %%sql
# SELECT "title", "author" FROM "longlist" LIMIT 5
# Out:
#  * sqlite:///SQL/src0/longlist.db
# Done.
# [('Boulder', 'Eva Baltasar'),
#  ('Whale', 'Cheon Myeong-Kwan'),
#  ('The Gospel According to the New World', 'Maryse Condé'),
#  ('Standing Heavy', 'Gauz'),
#  ('Time Shelter', 'Georgi Gospodinov')]

# %% [markdown]
# # WHERE year >= 2023

# %%
# %%sql
# SELECT "title", "author", "year" FROM "longlist" WHERE "year" >= 2023
# Out:
#  * sqlite:///SQL/src0/longlist.db
# Done.
# [('Boulder', 'Eva Baltasar', 2023),
#  ('Whale', 'Cheon Myeong-Kwan', 2023),
#  ('The Gospel According to the New World', 'Maryse Condé', 2023),
#  ('Standing Heavy', 'Gauz', 2023),
#  ('Time Shelter', 'Georgi Gospodinov', 2023),
#  ('Is Mother Dead', 'Vigdis Hjorth', 2023),
#  ('Jimi Hendrix Live in Lviv', 'Andrey Kurkov', 2023),
#  ('The Birthday Party', 'Laurent Mauvignier', 2023),
#  ('While We Were Dreaming', 'Clemens Meyer', 2023),
#  ('Pyre', 'Perumal Murugan', 2023),
#  ('Still Born', 'Guadalupe Nettel', 2023),
#  ('A System So Magnificent It Is Blinding', 'Amanda Svensson', 2023),
#  ('Ninth Building', 'Zou Jingzhi', 2023)]

# %% [markdown]
# # Where a certain Author

# %%
# %%sql
# SELECT "author" FROM "longlist" ORDER BY('author') ASC;
# Out:
#  * sqlite:///SQL/src0/longlist.db
# Done.
# [('Eva Baltasar',),
#  ('Cheon Myeong-Kwan',),
#  ('Maryse Condé',),
#  ('Gauz',),
#  ('Georgi Gospodinov',),
#  ('Vigdis Hjorth',),
#  ('Andrey Kurkov',),
#  ('Laurent Mauvignier',),
#  ('Clemens Meyer',),
#  ('Perumal Murugan',),
#  ('Guadalupe Nettel',),
#  ('Amanda Svensson',),
#  ('Zou Jingzhi',),
#  ('Fernanda Melchor',),
#  ('Mieko Kawakami',),
#  ('Sang Young Park',),
#  ('Norman Erikson Pasaribu',),
#  ('Claudia Piñeiro',),
#  ('Violaine Huisman',),
#  ('David Grossman',),
#  ('Paulo Scott',),
#  ('Jon Fosse',),
#  ('Jonas Eika',),
#  ('Geentanjali Shree',),
#  ('Olga Tokarczuk',),
#  ('Bora Chung',),
#  ('Éric Vuillard',),
#  ('Benajamín Labatut',),
#  ('Andrzej Tichy',),
#  ('Judith Schalansky',),
#  ('David Diop',),
#  ('Can Xue',),
#  ('Maria Stepanova',),
#  ('Adania Shibli',),
#  ('Jaap Robben',),
#  ('Mariana Enríquez',),
#  ('Olga Ravn',),
#  ('Nana Ekvtimishvili',),
#  ("Ngũgĩ wa Thiong'o",),
# ...
